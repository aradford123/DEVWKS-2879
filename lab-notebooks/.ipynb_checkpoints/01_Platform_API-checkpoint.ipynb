# %% [markdown]
# Plaform Enrichment API for DNA-Center

# %%
from util import get_url
import json
import time

# %% [markdown]
# Wired client

# %%
headers =  {'entity_type': 'mac_address', 
            'entity_value': '00:00:2A:01:00:04'}

response = get_url("dna/intent/api/v1/user-enrichment", headers=headers)
# Out:
# https://sandboxdnac2.cisco.com:8080/dna/intent/api/v1/user-enrichment

# %%
print (json.dumps(response,indent=2))
# Out:
# [
#   {
#     "userDetails": {
#       "id": "00:00:2A:01:00:04",
#       "connectionStatus": "CONNECTED",
#       "hostType": "WIRED",
#       "userId": null,
#       "hostName": null,
#       "hostOs": null,
#       "hostVersion": null,
#       "subType": "Unclassified",
#       "lastUpdated": 1580215380000,
#       "healthScore": [
#         {
#           "healthType": "OVERALL",
#           "reason": "",
#           "score": 10
#         },
#         {
#           "healthType": "ONBOARDED",
#           "reason": "",
#           "score": 4
#         },
#         {
#           "healthType": "CONNECTED",
#           "reason": "",
#           "score": 6
#         }
#       ],
#       "hostMac": "00:00:2A:01:00:04",
#       "hostIpV4": "10.10.20.163",
#       "authType": "None",
#       "vlanId": 823,
#       "vnid": 0,
#       "ssid": "sandbox",
#       "frequency": null,
#       "channel": null,
#       "apGroup": null,
#       "location": "USA/Chicago/CHG5/First Floor",
#       "clientConnection": "leaf2.labb.local",
#       "connectedDevice": [
#         {
#           "type": null,
#           "name": null,
#           "id": "d101ef07-b508-4cc9-bfe3-2acf7e8a1015",
#           "ip address": null,
#           "band": null
#         }
#       ],
#       "issueCount": 0,
#       "rssi": "0.0",
#       "avgRssi": "0.0",
#       "snr": "0.0",
#       "avgSnr": "0.0",
#       "dataRate": "0.0",
#       "txBytes": "2021836.0",
#       "rxBytes": "2280251.0",
#       "dnsResponse": "0.0",
#       "dnsRequest": "0.0",
#       "onboarding": {
#         "averageRunDuration": "0.0",
#         "maxRunDuration": "0.0",
#         "averageAssocDuration": "0.0",
#         "maxAssocDuration": "0.0",
#         "averageAuthDuration": "0.0",
#         "maxAuthDuration": "0.0",
#         "averageDhcpDuration": "0.0",
#         "maxDhcpDuration": "0.0",
#         "aaaServerIp": "N/A",
#         "dhcpServerIp": "UNKNOWN",
#         "authDoneTime": 0,
#         "assocDoneTime": 0,
#         "dhcpDoneTime": 0,
#         "aaaRootcauseList": [
#           "SUCCESS"
#         ]
#       },
#       "clientType": "OLD",
#       "onboardingTime": 0,
#       "port": "GigabitEthernet1/0/4",
#       "iosCapable": false,
#       "usage": 4302087,
#       "linkSpeed": 1000000000,
#       "remoteEndDuplexMode": "Full Duplex",
#       "txLinkError": 0,
#       "rxLinkError": 0,
#       "txRate": 53916.525275421256,
#       "rxRate": 60807.720128668814,
#       "versionTime": null,
#       "dot11Protocol": "PROTOCOL_802_11_UNKNOWN",
#       "slotId": 0
#     },
#     "connectedDevice": [
#       {
#         "deviceDetails": {
#           "family": "Switches and Hubs",
#           "type": "Cisco Catalyst 9300 Switch",
#           "location": null,
#           "errorCode": null,
#           "macAddress": "50:61:bf:ec:07:80",
#           "role": "ACCESS",
#           "apManagerInterfaceIp": "",
#           "associatedWlcIp": "",
#           "bootDateTime": "2019-04-20 10:29:12",
#           "collectionStatus": "Managed",
#           "interfaceCount": "0",
#           "lineCardCount": "0",
#           "lineCardId": "",
#           "managementIpAddress": "10.10.20.82",
#           "memorySize": "NA",
#           "platformId": "C9300-48U",
#           "reachabilityFailureReason": "",
#           "reachabilityStatus": "Reachable",
#           "snmpContact": "",
#           "snmpLocation": "",
#           "tunnelUdpPort": null,
#           "waasDeviceMode": null,
#           "series": "Cisco Catalyst 9300 Series Switches",
#           "inventoryStatusDetail": "<status><general code=\"SUCCESS\"/></status>",
#           "collectionInterval": "Global Default",
#           "serialNumber": "FCW2214L0UZ",
#           "softwareVersion": "16.6.4a",
#           "roleSource": "MANUAL",
#           "hostname": "leaf2.labb.local",
#           "upTime": "283 days, 2:10:28.58",
#           "lastUpdateTime": 1580215152806,
#           "errorDescription": null,
#           "locationName": null,
#           "tagCount": "0",
#           "lastUpdated": "2020-01-28 12:39:12",
#           "instanceUuid": "d101ef07-b508-4cc9-bfe3-2acf7e8a1015",
#           "id": "d101ef07-b508-4cc9-bfe3-2acf7e8a1015",
#           "neighborTopology": [
#             {
#               "nodes": [
#                 {
#                   "role": "ACCESS",
#                   "name": "spine1.abc.in.labb.local",
#                   "id": "b558bdcc-6835-4420-bfe8-26efa3fcf0b9",
#                   "description": null,
#                   "deviceType": "Cisco Catalyst38xx stack-able ethernet switch",
#                   "platformId": "WS-C3850-24P-L",
#                   "family": "Switches and Hubs",
#                   "ip": "10.10.20.80",
#                   "softwareVersion": "16.3.5b",
#                   "userId": null,
#                   "nodeType": "NetworkDevice",
#                   "radioFrequency": null,
#                   "clients": null,
#                   "count": null,
#                   "healthScore": 10,
#                   "level": 0,
#                   "fabricGroup": null,
#                   "connectedDevice": null
#                 },
#                 {
#                   "role": "ACCESS",
#                   "name": "3504_WLC",
#                   "id": "50c96308-84b5-43dc-ad68-cda146d80290",
#                   "description": null,
#                   "deviceType": "Cisco 3504 Wireless LAN Controller",
#                   "platformId": "AIR-CT3504-K9",
#                   "family": "Wireless Controller",
#                   "ip": "10.10.20.51",
#                   "softwareVersion": "8.5.140.0",
#                   "userId": null,
#                   "nodeType": "NetworkDevice",
#                   "radioFrequency": null,
#                   "clients": null,
#                   "count": null,
#                   "healthScore": -1,
#                   "level": 0,
#                   "fabricGroup": null,
#                   "connectedDevice": null
#                 },
#                 {
#                   "role": "ACCESS",
#                   "name": "leaf2.labb.local",
#                   "id": "d101ef07-b508-4cc9-bfe3-2acf7e8a1015",
#                   "description": null,
#                   "deviceType": "Cisco Catalyst 9300 Switch",
#                   "platformId": "C9300-48U",
#                   "family": "Switches and Hubs",
#                   "ip": "10.10.20.82",
#                   "softwareVersion": "16.6.4a",
#                   "userId": null,
#                   "nodeType": "NetworkDevice",
#                   "radioFrequency": null,
#                   "clients": 1,
#                   "count": null,
#                   "healthScore": 10,
#                   "level": 1,
#                   "fabricGroup": "Global/USA/Chicago_zzz",
#                   "connectedDevice": null
#                 },
#                 {
#                   "role": null,
#                   "name": "1 Client",
#                   "id": "CLIENTS",
#                   "description": null,
#                   "deviceType": null,
#                   "platformId": null,
#                   "family": "CLIENTS",
#                   "ip": null,
#                   "softwareVersion": null,
#                   "userId": null,
#                   "nodeType": "CLIENTS",
#                   "radioFrequency": null,
#                   "clients": null,
#                   "count": null,
#                   "healthScore": 10,
#                   "level": 2,
#                   "fabricGroup": null,
#                   "connectedDevice": null
#                 }
#               ],
#               "links": [
#                 {
#                   "source": "d101ef07-b508-4cc9-bfe3-2acf7e8a1015",
#                   "linkStatus": null,
#                   "sourceLinkStatus": "UP",
#                   "targetLinkStatus": "UP",
#                   "target": "b558bdcc-6835-4420-bfe8-26efa3fcf0b9",
#                   "id": "10.10.20.80-GigabitEthernet1/0/3",
#                   "portUtilization": null,
#                   "sourceInterfaceName": "GigabitEthernet1/0/3",
#                   "targetInterfaceName": "GigabitEthernet1/0/3",
#                   "sourceDuplexInfo": "FullDuplex",
#                   "targetDuplexInfo": "FullDuplex",
#                   "sourcePortMode": "trunk",
#                   "targetPortMode": "trunk",
#                   "sourceAdminStatus": "UP",
#                   "targetAdminStatus": "UP",
#                   "apRadioAdminStatus": null,
#                   "apRadioOperStatus": null,
#                   "sourcePortVLANInfo": "823",
#                   "targetPortVLANInfo": "823"
#                 },
#                 {
#                   "source": "d101ef07-b508-4cc9-bfe3-2acf7e8a1015",
#                   "linkStatus": null,
#                   "sourceLinkStatus": "UP",
#                   "targetLinkStatus": "UP",
#                   "target": "50c96308-84b5-43dc-ad68-cda146d80290",
#                   "id": "10.10.20.51-GigabitEthernet1/0/4",
#                   "portUtilization": null,
#                   "sourceInterfaceName": "GigabitEthernet1/0/4",
#                   "targetInterfaceName": "GigabitEthernet0/0/1",
#                   "sourceDuplexInfo": "FullDuplex",
#                   "targetDuplexInfo": "AutoNegotiate",
#                   "sourcePortMode": "access",
#                   "targetPortMode": "auto",
#                   "sourceAdminStatus": "UP",
#                   "targetAdminStatus": "UP",
#                   "apRadioAdminStatus": null,
#                   "apRadioOperStatus": null,
#                   "sourcePortVLANInfo": "823",
#                   "targetPortVLANInfo": "0"
#                 },
#                 {
#                   "source": "d101ef07-b508-4cc9-bfe3-2acf7e8a1015",
#                   "linkStatus": null,
#                   "sourceLinkStatus": "UP",
#                   "targetLinkStatus": null,
#                   "target": "CLIENTS",
#                   "id": "CLIENTS",
#                   "portUtilization": null,
#                   "sourceInterfaceName": null,
#                   "targetInterfaceName": null,
#                   "sourceDuplexInfo": null,
#                   "targetDuplexInfo": null,
#                   "sourcePortMode": null,
#                   "targetPortMode": null,
#                   "sourceAdminStatus": null,
#                   "targetAdminStatus": null,
#                   "interfaceDetails": [
#                     {
#                       "clientMacAddress": "00:00:2A:01:00:07",
#                       "connectedDeviceIntName": "GigabitEthernet1/0/4",
#                       "duplex": "FullDuplex",
#                       "portMode": "access",
#                       "adminStatus": "UP"
#                     },
#                     {
#                       "clientMacAddress": "00:00:2A:01:00:08",
#                       "connectedDeviceIntName": "GigabitEthernet1/0/4",
#                       "duplex": "FullDuplex",
#                       "portMode": "access",
#                       "adminStatus": "UP"
#                     },
#                     {
#                       "clientMacAddress": "00:00:2A:01:00:01",
#                       "connectedDeviceIntName": "GigabitEthernet1/0/4",
#                       "duplex": "FullDuplex",
#                       "portMode": "access",
#                       "adminStatus": "UP"
#                     },
#                     {
#                       "clientMacAddress": "00:00:2A:01:00:0B",
#                       "connectedDeviceIntName": "GigabitEthernet1/0/4",
#                       "duplex": "FullDuplex",
#                       "portMode": "access",
#                       "adminStatus": "UP"
#                     },
#                     {
#                       "clientMacAddress": "00:00:2A:01:00:02",
#                       "connectedDeviceIntName": "GigabitEthernet1/0/4",
#                       "duplex": "FullDuplex",
#                       "portMode": "access",
#                       "adminStatus": "UP"
#                     },
#                     {
#                       "clientMacAddress": "00:00:2A:01:00:05",
#                       "connectedDeviceIntName": "GigabitEthernet1/0/4",
#                       "duplex": "FullDuplex",
#                       "portMode": "access",
#                       "adminStatus": "UP"
#                     },
#                     {
#                       "clientMacAddress": "00:00:2A:01:00:0C",
#                       "connectedDeviceIntName": "GigabitEthernet1/0/4",
#                       "duplex": "FullDuplex",
#                       "portMode": "access",
#                       "adminStatus": "UP"
#                     },
#                     {
#                       "clientMacAddress": "00:00:2A:01:00:03",
#                       "connectedDeviceIntName": "GigabitEthernet1/0/4",
#                       "duplex": "FullDuplex",
#                       "portMode": "access",
#                       "adminStatus": "UP"
#                     },
#                     {
#                       "clientMacAddress": "00:00:2A:01:00:04",
#                       "connectedDeviceIntName": "GigabitEthernet1/0/4",
#                       "duplex": "FullDuplex",
#                       "portMode": "access",
#                       "adminStatus": "UP"
#                     },
#                     {
#                       "clientMacAddress": "00:19:06:21:55:41",
#                       "connectedDeviceIntName": "GigabitEthernet1/0/1",
#                       "duplex": "FullDuplex",
#                       "portMode": "access",
#                       "adminStatus": "UP"
#                     }
#                   ],
#                   "apRadioAdminStatus": null,
#                   "apRadioOperStatus": null,
#                   "sourcePortVLANInfo": null,
#                   "targetPortVLANInfo": null
#                 }
#               ]
#             }
#           ]
#         }
#       }
#     ]
#   }
# ]

# %%
from fake_issue_enrichment import issue

# %%
import json
print (json.dumps(issue,indent=2))
# Out:
# {
#   "issueDetails": {
#     "issue": [
#       {
#         "issueId": "AWPuxkGB_Vn43OLUwqjI",
#         "issueSource": "Cisco DNA",
#         "issueCategory": "Onboarding",
#         "issueName": "wireless_client_onboarding",
#         "issueDescription": "This client is taking longer than expected time to connect to 'sda' SSID due to excessive authentication time.<ul><li>Onboarding took 31.4 seconds seconds(expected time should be less than 10.0 seconds).</li><li>802.11 Association took less than a second (expected time should be less than 2.0 seconds).</li><li>Authentication and Key Exchange took less than a second (expected time should be less than 3.0 seconds)</li><li>IP Addressing took 0 seconds (expected time should be less than 5.0 seconds)</li><li>This client tried to onboard 1 times which took 31.1 seconds </li></ul><br>The authentication delay is because the client is slow to respond to authentication messages.The client was connecting to 'sda' SSID on 5.0 GHz radio on 'adam-sda-3802' AP  in 'Global/north sydney/level 22'. The AP was connected to '3504' WLC.",
#         "issueEntity": "Client",
#         "issueEntityValue": "00:26:08:E0:F4:97",
#         "issueSeverity": "HIGH",
#         "issuePriority": "",
#         "issueSummary": "Wireless client took a long time to connect (SSID: sda, AP: adam-sda-3802, Band: 5.0 GHz, Site: Global/north sydney/level 22) - Excessive time due to RF issues",
#         "issueTimestamp": 1528719213433,
#         "suggestedActions": [
#           {
#             "message": "Check whether the client moved during the authentication phase, since a moving client may cause packet losses and retries.",
#             "steps": []
#           },
#           {
#             "message": "Check for a recent OS update, since this may have been fixed in an update.",
#             "steps": []
#           },
#           {
#             "message": "Check the RF conditions at the client location. Since bad RF condition will leads to packet losses and higher retries.",
#             "steps": []
#           },
#           {
#             "message": "Check if fragmentation is occurring in the network, since this may lead to additional processing delays.",
#             "steps": []
#           },
#           {
#             "message": "Check WLC EAP Identity request timeout as the client may have not responded to this request in time.",
#             "steps": []
#           }
#         ],
#         "impactedHosts": [
#           {
#             "hostType": "WIRELESS",
#             "hostName": "adams-MBP",
#             "hostOs": "Apple-Device",
#             "ssid": "sda",
#             "connectedInterface": "Unknown",
#             "macAddress": "00:26:08:E0:F4:97",
#             "failedAttempts": 1,
#             "location": {
#               "siteId": "305ed723-2e48-499b-a383-49103b15af54",
#               "siteType": "FLOOR",
#               "area": "Global",
#               "building": "north sydney",
#               "floor": "level 22",
#               "apsImpacted": [
#                 "CC:16:7E:92:2B:40"
#               ]
#             },
#             "timestamp": 1528719213433
#           }
#         ]
#       },
#       {
#         "issueId": "AWPuxGva_Vn43OLUwqjF",
#         "issueSource": "Cisco DNA",
#         "issueCategory": "Onboarding",
#         "issueName": "wireless_client_onboarding",
#         "issueDescription": null,
#         "issueEntity": "Client",
#         "issueEntityValue": "00:26:08:E0:F4:97",
#         "issueSeverity": "HIGH",
#         "issuePriority": "",
#         "issueSummary": "Wireless client failed to roam (SSID: sda, AP: adam-sda-3802, Band: 5.0 GHz, Site: Global/north sydney/level 22) - Failed to authenticate due to Client Timeout",
#         "issueTimestamp": 1528719093228,
#         "suggestedActions": [
#           {
#             "message": "Verify whether the client software has gone through a recent update since this may be a recent change of behavior.",
#             "steps": []
#           },
#           {
#             "message": "If the failed attempt is associated with a client that is located outdoors, consider introducing Low RSSI Threshold to the setup since this will force the client to join an AP with a stronger signal. Also check the AP location for RF Issues. Make sure the AP is in client's line of sight.",
#             "steps": []
#           }
#         ],
#         "impactedHosts": [
#           {
#             "hostType": "WIRELESS",
#             "hostName": "adams-MBP",
#             "hostOs": "Apple-Device",
#             "ssid": "sda",
#             "connectedInterface": "Unknown",
#             "macAddress": "00:26:08:E0:F4:97",
#             "failedAttempts": 1,
#             "location": {
#               "siteId": "305ed723-2e48-499b-a383-49103b15af54",
#               "siteType": "FLOOR",
#               "area": "Global",
#               "building": "north sydney",
#               "floor": "level 22",
#               "apsImpacted": [
#                 "CC:16:7E:92:2B:40"
#               ]
#             },
#             "timestamp": 1528719093228
#           }
#         ]
#       },
#       {
#         "issueId": "AWPuwMML_Vn43OLUwqi9",
#         "issueSource": "Cisco DNA",
#         "issueCategory": "Onboarding",
#         "issueName": "wireless_client_onboarding",
#         "issueDescription": null,
#         "issueEntity": "Client",
#         "issueEntityValue": "00:26:08:E0:F4:97",
#         "issueSeverity": "HIGH",
#         "issuePriority": "",
#         "issueSummary": "Wireless client failed to roam (SSID: sda, AP: adam-sda-3802, Band: 5.0 GHz, Site: Unknown) - Failed to authenticate due to Client Timeout",
#         "issueTimestamp": 1528718854206,
#         "suggestedActions": [
#           {
#             "message": "Verify whether the client software has gone through a recent update since this may be a recent change of behavior.",
#             "steps": []
#           },
#           {
#             "message": "If the failed attempt is associated with a client that is located outdoors, consider introducing Low RSSI Threshold to the setup since this will force the client to join an AP with a stronger signal. Also check the AP location for RF Issues. Make sure the AP is in client's line of sight.",
#             "steps": []
#           }
#         ],
#         "impactedHosts": [
#           {
#             "hostType": "WIRELESS",
#             "hostName": "adams-MBP",
#             "hostOs": "Apple-Device",
#             "ssid": "sda",
#             "connectedInterface": "Unknown",
#             "macAddress": "00:26:08:E0:F4:97",
#             "failedAttempts": 1,
#             "location": {
#               "siteId": "UNASSIGNED",
#               "siteType": "BUILDING",
#               "area": "Global",
#               "building": "UNASSIGNED",
#               "floor": null,
#               "apsImpacted": [
#                 "CC:16:7E:92:2B:40"
#               ]
#             },
#             "timestamp": 1528718854206
#           }
#         ]
#       },
#       {
#         "issueId": "AWPsCspD_Vn43OLUwqUd",
#         "issueSource": "Cisco DNA",
#         "issueCategory": "Onboarding",
#         "issueName": "wireless_client_onboarding",
#         "issueDescription": "This client is taking longer than expected time to connect to 'sda' SSID due to excessive authentication time.<ul><li>Onboarding took 29.8 seconds (expected time should be less than 10.0 seconds).</li><li>Association took\u00a0less than a second (expected time should be less than\u00a02.0\u00a0seconds)</li><li>Authentication and Key Exchange took 29.8 seconds (expected time should be less than\u00a03.0\u00a0seconds)</li><li>IP Addressing took 0 seconds (expected time should be less than\u00a05.0\u00a0seconds)</li></ul><br>The reason for the longer authentication time is delays from the AAA server or the network.The client itself is responding in time.The client was connecting to 'sda' SSID on 5.0 GHz radio on 'adam-sda-3802' AP in 'Global/north sydney/level 22'. The AP was connected to '3504' WLC.",
#         "issueEntity": "Client",
#         "issueEntityValue": "00:26:08:E0:F4:97",
#         "issueSeverity": "HIGH",
#         "issuePriority": "",
#         "issueSummary": "Wireless client took a long time to connect (SSID: sda, AP: adam-sda-3802, Band: 5.0 GHz) - Excessive time for Authentication due to AAA server or Network delays",
#         "issueTimestamp": 1528673434050,
#         "suggestedActions": [
#           {
#             "message": "Verify the network connectivity to the AAA server. Since there may be network glitch causing retries that leads to texcessive onboarding times.",
#             "steps": []
#           },
#           {
#             "message": "Verify whether the AAA server is responding to requests.",
#             "steps": []
#           },
#           {
#             "message": "Check the network load between the AP and the WLC, and between the WLC and the AAA server. Since excessive traffic can cause additional delays.",
#             "steps": []
#           }
#         ],
#         "impactedHosts": [
#           {
#             "hostType": "WIRELESS",
#             "hostName": "adams-MBP",
#             "hostOs": "Apple-Device",
#             "ssid": "sda",
#             "connectedInterface": "Unknown",
#             "macAddress": "00:26:08:E0:F4:97",
#             "failedAttempts": 1,
#             "location": {
#               "siteId": "305ed723-2e48-499b-a383-49103b15af54",
#               "siteType": "FLOOR",
#               "area": "Global",
#               "building": "north sydney",
#               "floor": "level 22",
#               "apsImpacted": [
#                 "CC:16:7E:92:2B:40"
#               ]
#             },
#             "timestamp": 1528673434050
#           }
#         ]
#       }
#     ]
#   }
# }
