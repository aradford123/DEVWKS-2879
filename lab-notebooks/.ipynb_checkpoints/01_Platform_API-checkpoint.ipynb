# %% [markdown]
# Plaform Enrichment API for DNA-Center

# %%
from util import get_url
import json
import time

# %% [markdown]
# Wired client

# %%
headers =  {'entity_type': 'mac_address', 
            'entity_value': '00:00:2A:01:00:04'}

response = get_url("dna/intent/api/v1/user-enrichment", headers=headers)

# %%
print (json.dumps(response,indent=2))

# %% [markdown]
# Wireless Client

# %%
headers =  {'entity_type': 'mac_address', 
            'entity_value': '00:00:2A:01:00:2F'}

response = get_url("dna/intent/api/v1/user-enrichment", headers=headers)

# %%
print (json.dumps(response,indent=2))

# %%
headers =  {'entity_type': 'ip_address', 
            'entity_value': '10.10.20.51'}

response = get_url("dna/intent/api/v1/device-enrichment", headers=headers)
# Out:
# https://sandboxdnac2.cisco.com:443/dna/intent/api/v1/device-enrichment

# %%
print (json.dumps(response,indent=2))
# Out:
# [
#   {
#     "deviceDetails": {
#       "family": "Wireless Controller",
#       "type": "Cisco 3504 Wireless LAN Controller",
#       "location": null,
#       "errorCode": "ERROR-CONNECTION-CLOSED",
#       "macAddress": "50:61:bf:57:2f:00",
#       "role": "ACCESS",
#       "apManagerInterfaceIp": "",
#       "associatedWlcIp": "",
#       "bootDateTime": "2019-03-18 09:38:20",
#       "collectionStatus": "Partial Collection Failure",
#       "interfaceCount": "0",
#       "lineCardCount": "0",
#       "lineCardId": "",
#       "managementIpAddress": "10.10.20.51",
#       "memorySize": "3735302144",
#       "platformId": "AIR-CT3504-K9",
#       "reachabilityFailureReason": "",
#       "reachabilityStatus": "Reachable",
#       "snmpContact": "",
#       "snmpLocation": "",
#       "tunnelUdpPort": "16666",
#       "waasDeviceMode": null,
#       "series": "Cisco 3500 Series Wireless LAN Controller",
# ...

# %%
from fake_issue_enrichment import issue

# %%
import json
print (json.dumps(issue,indent=2))
# Out:
# {
#   "issueDetails": {
#     "issue": [
#       {
#         "issueId": "AWPuxkGB_Vn43OLUwqjI",
#         "issueSource": "Cisco DNA",
#         "issueCategory": "Onboarding",
#         "issueName": "wireless_client_onboarding",
# ...
